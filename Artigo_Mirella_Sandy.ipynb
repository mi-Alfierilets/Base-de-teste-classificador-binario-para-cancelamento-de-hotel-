# %%
#Importando a biblioteca Pandas
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/mi-Alfierilets/Base-de-teste-classificador-binario-para-cancelamento-de-hotel-/refs/heads/main/hotel_booking.csv'
#df = pd.read_csv('titanic_modificado.csv')
df = pd.read_csv(url)

# %%
#Exibir o DataFrame
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#Informações do DataFrame carregado

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Primeiros registros

df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
#Forma/Dimensões do DataFrame (linhas x colunas)
df.shape
# Out:
# (119390, 36)

# %%
#Verificando se as classes status da reserva
df["reservation_status"].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
#Como selecionar registros num DataFrame?
#Visualizar todos os os hospides que cancelaram
df[df["reservation_status"]== "Canceled"]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 8       Resort Hotel            1         85               2015
# 9       Resort Hotel            1         75               2015
# 10      Resort Hotel            1         23               2015
# 27      Resort Hotel            1         60               2015
# 32      Resort Hotel            1         96               2015
# ...              ...          ...        ...                ...
# 107997    City Hotel            1         13               2017
# 108000    City Hotel            1         13               2017
# 110280    City Hotel            1        132               2017
# 111355    City Hotel            1          4               2017
# 111924    City Hotel            1          7               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 8                    July                        27
# 9                    July                        27
# ...

# %%
#Como selecionar registros num DataFrame?
#Exemplo: Visualizar todos os os hospides que compareceram a reserva já feita
df[df["reservation_status"]== "Check-Out"]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 33319  Resort Hotel            0         12               2017
# 33320  Resort Hotel            0         17               2017
# 33321  Resort Hotel            0         16               2017
# 33322  Resort Hotel            0         73               2017
# 33323  Resort Hotel            0         73               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                      27.0                        1.0
# ...

# %%
# Visualizar todos os os hospides que não compareceram
df[df["reservation_status"]== "No-Show"]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 122     Resort Hotel            1         36               2015
# 328     Resort Hotel            1         55               2015
# 343     Resort Hotel            1         47               2015
# 467     Resort Hotel            1          6               2015
# 472     Resort Hotel            1          3               2015
# ...              ...          ...        ...                ...
# 104650    City Hotel            1          1               2017
# 108459    City Hotel            1         31               2017
# 108829    City Hotel            1         25               2017
# 111925    City Hotel            1          6               2017
# 117295    City Hotel            1          0               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 122                  July                        27
# 328                  July                        29
# ...

# %%
#Verificando se as classes hotel
df["hotel"].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
#Verificando se as classes da variável-alvo estão balanceadas
df["is_canceled"].value_counts()
# Out:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %%
#Verificando se as classes alvo e o status da reserva esão iguais
df["reservation_status"].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
#Identificando a quantidade de dados nulos
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#apagando os registros dos que não comparecerão
df = df[df['reservation_status'] != 'No-Show']

# %%
#Verificando se as classes status da reserva
df["reservation_status"].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# Name: count, dtype: int64

# %%
#Removendo colunas que são "irrelevantes" para nossa análise
df.drop(columns=["name", "arrival_date_year", "arrival_date_month", "arrival_date_week_number", "arrival_date_day_of_month", "children","babies", "email","phone-number","credit_card" ,"country","adr","company","deposit_type","market_segment", "distribution_channel","customer_type","total_of_special_requests","assigned_room_type","required_car_parking_spaces","reservation_status_date","agent"],inplace=True)
# Out:
# <ipython-input-188-1da9af197227>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["name", "arrival_date_year", "arrival_date_month", "arrival_date_week_number", "arrival_date_day_of_month", "children","babies", "email","phone-number","credit_card" ,"country","adr","company","deposit_type","market_segment", "distribution_channel","customer_type","total_of_special_requests","assigned_room_type","required_car_parking_spaces","reservation_status_date","agent"],inplace=True)

# %%
df
# Out:
#                hotel  is_canceled  lead_time  stays_in_weekend_nights  \
# 0       Resort Hotel            0        342                        0
# 1       Resort Hotel            0        737                        0
# 2       Resort Hotel            0          7                        0
# 3       Resort Hotel            0         13                        0
# 4       Resort Hotel            0         14                        0
# ...              ...          ...        ...                      ...
# 119385    City Hotel            0         23                        2
# 119386    City Hotel            0        102                        2
# 119387    City Hotel            0         34                        2
# 119388    City Hotel            0        109                        2
# 119389    City Hotel            0        205                        2
#
#         stays_in_week_nights  adults meal  is_repeated_guest  \
# 0                          0       2   BB                  0
# ...

# %%
#Identificando a quantidade de dados nulos
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# meal                              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# booking_changes                   0
# days_in_waiting_list              0
# reservation_status                0
# dtype: int64

# %%
#Informações do DataFrame carregado

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118183 entries, 0 to 119389
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118183 non-null  object
#  1   is_canceled                     118183 non-null  int64
#  2   lead_time                       118183 non-null  int64
#  3   stays_in_weekend_nights         118183 non-null  int64
#  4   stays_in_week_nights            118183 non-null  int64
#  5   adults                          118183 non-null  int64
#  6   meal                            118183 non-null  object
#  7   is_repeated_guest               118183 non-null  int64
#  8   previous_cancellations          118183 non-null  int64
#  9   previous_bookings_not_canceled  118183 non-null  int64
#  10  reserved_room_type              118183 non-null  object
#  11  booking_changes                 118183 non-null  int64
# ...

# %%
# Transformar 'hotel' em coluna numérica.
df['hotel'] = df['hotel'].map({'Resort Hotel': 0, 'City Hotel': 1, })
# Out:
# <ipython-input-192-f83415053eac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hotel'] = df['hotel'].map({'Resort Hotel': 0, 'City Hotel': 1, })

# %%
#Verificando se as classes hotel
df["hotel"].value_counts()
# Out:
# hotel
# 1    78414
# 0    39769
# Name: count, dtype: int64

# %%
# Transformar 'meal' em coluna numérica
df['meal'] = df['meal'].map({'BB': 0, 'HB': 1,'SC':2,'Undefined':3, 'FB':4})
# Out:
# <ipython-input-194-332afbb95cd5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['meal'] = df['meal'].map({'BB': 0, 'HB': 1,'SC':2,'Undefined':3, 'FB':4})

# %%
#Verificando se as classes meal
df["meal"].value_counts()
# Out:
# meal
# 0    91329
# 1    14408
# 2    10486
# 3     1167
# 4      793
# Name: count, dtype: int64

# %%
# Transformar 'reservd_room_type' em coluna numérica.
df['reserved_room_type'] = df['reserved_room_type'].map({'A': 0, 'B': 1,'C':2,'D':3, 'E':4, 'F':5, "G":6, "H":7, "L":8, "P":9})
# Out:
# <ipython-input-200-b1e3c1330b8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reserved_room_type'] = df['reserved_room_type'].map({'A': 0, 'B': 1,'C':2,'D':3, 'E':4, 'F':5, "G":6, "H":7, "L":8, "P":9})

# %%
#Verificando se as classes reserved_room_type
df["reserved_room_type"].value_counts()
# Out:
# reserved_room_type
# 0    85120
# 3    19013
# 4     6465
# 5     2860
# 6     2085
# 1     1103
# 2      924
# 7      595
# 9       12
# 8        6
# Name: count, dtype: int64

# %%
df
# Out:
#         hotel  is_canceled  lead_time  stays_in_weekend_nights  \
# 0           0            0        342                        0
# 1           0            0        737                        0
# 2           0            0          7                        0
# 3           0            0         13                        0
# 4           0            0         14                        0
# ...       ...          ...        ...                      ...
# 119385      1            0         23                        2
# 119386      1            0        102                        2
# 119387      1            0         34                        2
# 119388      1            0        109                        2
# 119389      1            0        205                        2
#
#         stays_in_week_nights  adults  meal  is_repeated_guest  \
# 0                          0       2     0                  0
# 1                          0       2     0                  0
# ...

# %%
#Informações do DataFrame carregado

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118183 entries, 0 to 119389
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118183 non-null  int64
#  1   is_canceled                     118183 non-null  int64
#  2   lead_time                       118183 non-null  int64
#  3   stays_in_weekend_nights         118183 non-null  int64
#  4   stays_in_week_nights            118183 non-null  int64
#  5   adults                          118183 non-null  int64
#  6   meal                            118183 non-null  int64
#  7   is_repeated_guest               118183 non-null  int64
#  8   previous_cancellations          118183 non-null  int64
#  9   previous_bookings_not_canceled  118183 non-null  int64
#  10  reserved_room_type              0 non-null       float64
#  11  booking_changes                 118183 non-null  int64
# ...

# %%
#Verificando se as classes da variável-alvo estão balanceadas
df["is_canceled"].value_counts()
# Out:
# is_canceled
# 0    75166
# 1    43017
# Name: count, dtype: int64

# %%
#Estatísticas Descritivas
# Visualizar estatísticas descritivas gerais
df.describe()
# Out:
#                hotel    is_canceled      lead_time  stays_in_weekend_nights  \
# count  118183.000000  118183.000000  118183.000000            118183.000000
# mean        0.663496       0.363986     104.489681                 0.925886
# std         0.472515       0.481147     107.090738                 0.995870
# min         0.000000       0.000000       0.000000                 0.000000
# 25%         0.000000       0.000000      18.000000                 0.000000
# 50%         1.000000       0.000000      70.000000                 1.000000
# 75%         1.000000       1.000000     161.000000                 2.000000
# max         1.000000       1.000000     737.000000                19.000000
#
#        stays_in_week_nights         adults           meal  is_repeated_guest  \
# count         118183.000000  118183.000000  118183.000000      118183.000000
# mean               2.499141       1.858381       0.355830           0.031857
# ...

# %%
#Visualização de Dados com Matplotlib e Seaborn

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Gráfico de Barras das Classes da coluna-alvo
sns.countplot(x='is_canceled', hue='is_canceled', data=df, palette={0: 'red', 1: 'blue'}, legend=True)
plt.title('Distribuição hóspedes que cancelaram ou não suas reservas  (0 = Não Cancelou , 1 = Cancelou)')
plt.xlabel('Cancelamento')
plt.ylabel('Número ')
plt.show()

# %%
# Mapa de calor com correlação
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Correlação entre Variáveis Numéricas")
plt.show()

# %%
#Construindo um Classificador Binário

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Separar variáveis explicativas e alvo
X = df.drop(columns=['is_canceled'])
y = df['is_canceled']

# %%
# Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
df
# Out:
#         hotel  is_canceled  lead_time  stays_in_weekend_nights  \
# 0           0            0        342                        0
# 1           0            0        737                        0
# 2           0            0          7                        0
# 3           0            0         13                        0
# 4           0            0         14                        0
# ...       ...          ...        ...                      ...
# 119385      1            0         23                        2
# 119386      1            0        102                        2
# 119387      1            0         34                        2
# 119388      1            0        109                        2
# 119389      1            0        205                        2
#
#         stays_in_week_nights  adults  meal  is_repeated_guest  \
# 0                          0       2     0                  0
# 1                          0       2     0                  0
# ...

# %%
#Informações do DataFrame carregado

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118183 entries, 0 to 119389
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118183 non-null  int64
#  1   is_canceled                     118183 non-null  int64
#  2   lead_time                       118183 non-null  int64
#  3   stays_in_weekend_nights         118183 non-null  int64
#  4   stays_in_week_nights            118183 non-null  int64
#  5   adults                          118183 non-null  int64
#  6   meal                            118183 non-null  int64
#  7   is_repeated_guest               118183 non-null  int64
#  8   previous_cancellations          118183 non-null  int64
#  9   previous_bookings_not_canceled  118183 non-null  int64
#  10  reserved_room_type              0 non-null       float64
#  11  booking_changes                 118183 non-null  int64
# ...

# %%
#Removendo colunas que são "irrelevantes" para nossa análise

df.drop(columns=["reservation_status"],inplace=True)
# Out:
# <ipython-input-206-2f2437c7d520>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["reservation_status"],inplace=True)

# %%
# Separar variáveis explicativas e alvo
X = df.drop(columns=['is_canceled'])
y = df['is_canceled']

# %%
# Dividir em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Modelo de Regressão Logística
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=200)

# %%
# Previsões
y_pred = model.predict(X_test)

# %%
# Avaliação do modelo
print("Acurácia:", accuracy_score(y_test, y_pred))
# Out:
# Acurácia: 0.6972387413797917

# %%
#Exibir Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:\n", cm)
# Out:
# Matriz de Confusão:
#  [[20531  1947]
#  [ 8897  4442]]

# %%
# Extração dos valores da matriz (para classificação binária)
# Ordem esperada: [[VN, FP], [FN, VP]]
vn = cm[0, 0] #verdadeiro negativo
fp = cm[0, 1] #falso positivo
fn = cm[1, 0] #falso negativo
vp = cm[1, 1] #verdadeiro positivo

# Cálculo manual das métricas
acuracia = (vp + vn) / (vp + vn + fp + fn)
recall = vp / (vp + fn)
precisao = vp / (vp + fp)
especificidade = vn / (vn + fp)
f1 = (2 * precisao * recall) / (precisao + recall)

# Impressão dos resultados
print(f"Acurácia:        {acuracia:.4f}")
print(f"Recall:          {recall:.4f}")
print(f"Precisão:        {precisao:.4f}")
print(f"Especificidade:  {especificidade:.4f}")
print(f"F1 Score:        {f1:.4f}")
# Out:
# Acurácia:        0.6972
# Recall:          0.3330
# Precisão:        0.6953
# Especificidade:  0.9134
# F1 Score:        0.4503

# %%
#Avaliando e Comparando Modelos

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Árvore de Decisão
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
pred_tree = tree.predict(X_test)

# %%
# Importância das features (árvore)
importances = pd.Series(tree.feature_importances_, index=X.columns)
importances.sort_values(ascending=True).plot(kind='barh')
plt.title("Importância das Variáveis - Árvore de Decisão")
plt.show()

# %%
# KNN
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
pred_knn = knn.predict(X_test)

# %%
# Previsões
y_pred = model.predict(X_test)

# %%
# Avaliação comparativa
print("Acurácia - Decision Tree:", accuracy_score(y_test, pred_tree))
print("Acurácia - KNN:", accuracy_score(y_test, pred_knn))
# Out:
# Acurácia - Decision Tree: 0.7682106262389368
# Acurácia - KNN: 0.7536923807130692

# %%
print(f"Acurácia - Decision Tree: {acc_dt:.4f}")
print(f"Acurácia - KNN: {acc_knn:.4f}")

# Relatórios de classificação
print("\nRelatório - Decision Tree:")
print(classification_report(y_test, y_pred_dt))

print("\nRelatório - KNN:")
print(classification_report(y_test, y_pred_knn))

#  Matriz de confusão
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

sns.heatmap(confusion_matrix(y_test, y_pred_dt), annot=True, fmt='d', ax=axs[0], cmap='Blues')
axs[0].set_title('Decision Tree - Matriz de Confusão')
axs[0].set_xlabel('Previsto')
axs[0].set_ylabel('Real')

sns.heatmap(confusion_matrix(y_test, y_pred_knn), annot=True, fmt='d', ax=axs[1], cmap='Greens')
axs[1].set_title('KNN - Matriz de Confusão')
axs[1].set_xlabel('Previsto')
axs[1].set_ylabel('Real')

plt.tight_layout()
plt.show()
# Out:
# Acurácia - Decision Tree: 0.9415
# Acurácia - KNN: 0.9591
#
# Relatório - Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        63
#            1       0.97      0.94      0.95       108
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171
#
#
# Relatório - KNN:
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94        63
#            1       0.95      0.99      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
def calcular_especificidade(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    especificidade = tn / (tn + fp)
    return especificidade

# Avaliação dos modelos
for nome, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    y_pred = modelo.predict(X_test)

    acuracia = accuracy_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precisao = precision_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    especificidade = calcular_especificidade(y_test, y_pred)

    print(f"\nModelo: {nome}")
    print(f"Acurácia:        {acuracia:.4f}")
    print(f"Recall:          {recall:.4f}")
    print(f"Precisão:        {precisao:.4f}")
    print(f"Especificidade:  {especificidade:.4f}")
    print(f"F1 Score:        {f1:.4f}")
# Out:
# Modelo: Árvore de Decisão
# Acurácia:        0.9415
# Recall:          0.9352
# Precisão:        0.9712
# Especificidade:  0.9524
# F1 Score:        0.9528
#
# Modelo: KNN
# Acurácia:        0.9591
# Recall:          0.9907
# Precisão:        0.9469
# Especificidade:  0.9048
# F1 Score:        0.9683
